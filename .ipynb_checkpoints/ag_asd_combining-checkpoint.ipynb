# %%
# Numerical python library (pronounced "num-pie")
import numpy as np

# Dataframes in Python
import pandas as pd

# Python plotting library
import matplotlib.pyplot as plt

# Statistical plotting library we'll use
import seaborn as sns

sns.set(style='ticks', context='notebook')

# This is necessary to show the plotted figures inside the notebook -- "inline" with the notebook cells
# %matplotlib inline
# Out:
# /home/ucsd-train33/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
asd_metadata=pd.read_csv('asd_metadata.csv', dtype=str, index_col="survey_id")
ag_metadata=pd.read_csv('ag_10k_fecal.csv', dtype=str, index_col="SURVEY_ID")

# %%
ag_metadata.head(3)
# Out:
#                  #SampleID VIOSCREEN_MANNITOL VIOSCREEN_SFA100  \
# SURVEY_ID
# Unknown    10317.000027205            Unknown          Unknown
# No         10317.000028676            Unknown          Unknown
# No         10317.000034247            Unknown          Unknown
#
#           NON_FOOD_ALLERGIES_BEESTINGS VIOSCREEN_FINISHED TONSILS_REMOVED  \
# SURVEY_ID
# Unknown                          false            Unknown              No
# No                               false            Unknown              No
# No                               false            Unknown              No
#
#           VIOSCREEN_SFA170 VIOSCREEN_VEGETABLE_SERVINGS VIOSCREEN_SORBITOL  \
# SURVEY_ID
# Unknown            Unknown                      Unknown            Unknown
# No                 Unknown                      Unknown            Unknown
# No                 Unknown                      Unknown            Unknown
#
#           COUNTRY_OF_BIRTH     ...      shannon_1k  Unnamed: 444  \
# SURVEY_ID                      ...
# Unknown      United States     ...           428.5         137.8
# No           United States     ...           368.4         136.5
# No           United States     ...           120.3  5.0641350598
#
#            Unnamed: 445  Unnamed: 446 Unnamed: 447 Unnamed: 448 Unnamed: 449  \
# SURVEY_ID
# Unknown    5.5930629352  5.3857424177          NaN          NaN          NaN
# No         5.5618637909  5.3637009792          NaN          NaN          NaN
# No         4.8497723745           NaN          NaN          NaN          NaN
#
#           Unnamed: 450 Unnamed: 451 Unnamed: 452
# SURVEY_ID
# Unknown            NaN          NaN          NaN
# No                 NaN          NaN          NaN
# No                 NaN          NaN          NaN
#
# [3 rows x 452 columns]

# %%
#asd_metadata.head(10)
#asd_metadata.shape
asd_metadata=asd_metadata.rename(columns={'Unnamed: 5':"unit"})
asd_metadata.head(10)
# Out:
#                   ag_asd_timestamp person_with_asd relation_to_participant  \
# survey_id
# 92073008b616bc6b   10/15/2014 9:20              No                  Parent
# e59f57973c1cf213  10/24/2014 19:06             Yes                    Self
# 0ecfebf9009ce02c  11/22/2014 10:36              No             Unspecified
# 871a8f293384bc03   12/1/2014 13:04              No                  Parent
# e1b64400d639a922    12/2/2014 6:54              No                  Parent
# 3f85c3127e35181e   12/5/2014 19:53             Yes                    Self
# 0100b469f4db4242   12/6/2014 11:38              No                  Parent
# 12dfe98bb387bf2d  12/13/2014 12:53              No                  Parent
# 5d1d92f5c2205e46   12/14/2014 6:59              No                  Parent
# be7350ab0d81c982  12/16/2014 15:16              No                   Other
#
#                  age_diagnosed   unit  \
# survey_id
# 92073008b616bc6b             2  years
# e59f57973c1cf213            63  years
# 0ecfebf9009ce02c   Unspecified    NaN
# 871a8f293384bc03             2  years
# e1b64400d639a922             5  years
# 3f85c3127e35181e            27  years
# 0100b469f4db4242           2.5  years
# 12dfe98bb387bf2d             3  years
# 5d1d92f5c2205e46             2  years
# be7350ab0d81c982             0    NaN
#
#                                              initial_identification  \
# survey_id
# 92073008b616bc6b                         Developmental Pediatrician
# e59f57973c1cf213                              On-line questionnaire
# 0ecfebf9009ce02c                                        Unspecified
# 871a8f293384bc03                                       Psychologist
# e1b64400d639a922  Neurologist, Psychiatrist, School District, Se...
# 3f85c3127e35181e                                       Psychologist
# 0100b469f4db4242                                       Psychologist
# 12dfe98bb387bf2d                                       Psychiatrist
# 5d1d92f5c2205e46                                 Self/friend/parent
# be7350ab0d81c982                                 Self/friend/parent
#
#                                                  testings_performed  \
# survey_id
# 92073008b616bc6b                                         Don’t know
# e59f57973c1cf213                                         Don’t know
# 0ecfebf9009ce02c                                        Unspecified
# 871a8f293384bc03                              ADOS-T Toddler Module
# e1b64400d639a922  ADOS (Autism Diagnostic Observation Scale), AD...
# 3f85c3127e35181e  Don’t know, The initial diagnosis was by compa...
# 0100b469f4db4242  ADOS (Autism Diagnostic Observation Scale), GA...
# 12dfe98bb387bf2d                                         Don’t know
# 5d1d92f5c2205e46  ADOS (Autism Diagnostic Observation Scale), CA...
# be7350ab0d81c982                                         Don’t know
#
#                                                       symptom_onset  \
# survey_id
# 92073008b616bc6b                                        regressive
# e59f57973c1cf213                                    non-regressive
# 0ecfebf9009ce02c                                        Unspecified
# 871a8f293384bc03                                        Unspecified
# e1b64400d639a922                                        Unspecified
# 3f85c3127e35181e                                    non-regressive
# 0100b469f4db4242  non-regressive (not accompanied by a loss of p...
# 12dfe98bb387bf2d                                        regressive
# 5d1d92f5c2205e46                                        regressive
# be7350ab0d81c982                                    non-regressive
#
#                  social_communication_deficit_intensity  \
# survey_id
# 92073008b616bc6b                        Severe deficits
# e59f57973c1cf213                      Moderate deficits
# 0ecfebf9009ce02c                            Unspecified
# 871a8f293384bc03                          Mild deficits
# e1b64400d639a922                      Moderate deficits
# 3f85c3127e35181e                        Severe deficits
# 0100b469f4db4242                      Moderate deficits
# 12dfe98bb387bf2d                      Moderate deficits
# 5d1d92f5c2205e46                        Severe deficits
# be7350ab0d81c982                          Mild deficits
#
#                                             spoken_language ...  Unnamed: 83  \
# survey_id                                                   ...
# 92073008b616bc6b  Speaks but cannot speak in full sentences ...          NaN
# e59f57973c1cf213                                        Yes ...          NaN
# 0ecfebf9009ce02c                                Unspecified ...          NaN
# 871a8f293384bc03                                        Yes ...          NaN
# e1b64400d639a922                                        Yes ...          NaN
# 3f85c3127e35181e                                        Yes ...          NaN
# 0100b469f4db4242                                        Yes ...          NaN
# 12dfe98bb387bf2d                                        Yes ...          NaN
# 5d1d92f5c2205e46                      No – unable to speak. ...          NaN
# be7350ab0d81c982                                        Yes ...          NaN
#
#                  Unnamed: 84 Unnamed: 85 Unnamed: 86 Unnamed: 87 Unnamed: 88  \
# survey_id
# 92073008b616bc6b         NaN         NaN         NaN         NaN         NaN
# e59f57973c1cf213         NaN         NaN         NaN         NaN         NaN
# 0ecfebf9009ce02c         NaN         NaN         NaN         NaN         NaN
# 871a8f293384bc03         NaN         NaN         NaN         NaN         NaN
# e1b64400d639a922         NaN         NaN         NaN         NaN         NaN
# 3f85c3127e35181e         NaN         NaN         NaN         NaN         NaN
# 0100b469f4db4242         NaN         NaN         NaN         NaN         NaN
# 12dfe98bb387bf2d         NaN         NaN         NaN         NaN         NaN
# 5d1d92f5c2205e46         NaN         NaN         NaN         NaN         NaN
# be7350ab0d81c982         NaN         NaN         NaN         NaN         NaN
#
#                  Unnamed: 89 Unnamed: 90 Unnamed: 91
# survey_id
# 92073008b616bc6b         NaN         NaN         NaN  NaN
# e59f57973c1cf213         NaN         NaN         NaN  NaN
# 0ecfebf9009ce02c         NaN         NaN         NaN  NaN
# 871a8f293384bc03         NaN         NaN         NaN  NaN
# e1b64400d639a922         NaN         NaN         NaN  NaN
# 3f85c3127e35181e         NaN         NaN         NaN  NaN
# 0100b469f4db4242         NaN         NaN         NaN  NaN
# 12dfe98bb387bf2d         NaN         NaN         NaN  NaN
# 5d1d92f5c2205e46         NaN         NaN         NaN
# be7350ab0d81c982         NaN         NaN         NaN  NaN
#
# [10 rows x 92 columns]

# %%
ag_metadata.index.names=['survey_id'] #renaming the index colun so that they have the same name for both metadata
ag_metadata.head(10)
ag_metadata.shape
# Out:
# (4050, 452)

# %%
#ag_asd_metadata=pd.merge(asd_metadata,ag_metadata,how='left',  )

# %%
ag_asd_metadata=asd_metadata.join(ag_metadata, how='outer') #outer joining everything and replaces the extra cells with NaN

# %%
ag_asd_metadata.shape
# Out:
# (4124, 544)

# %%
ag_asd_metadata = ag_asd_metadata[pd.notnull(ag_asd_metadata['ag_asd_timestamp'])] #removing the rows that don't have timestamp

# %%
ag_asd_metadata.shape
# Out:
# (83, 544)

# %%
ag_asd_metadata.head(5)
# Out:
#                  ag_asd_timestamp person_with_asd relation_to_participant  \
# survey_id
# 0100b469f4db4242  12/6/2014 11:38              No                  Parent
# 01d86333e4604f40   3/7/2015 17:21              No                  Parent
# 024d1aaabac2af2b  5/14/2015 12:55              No                  Parent
# 050a74c5d1e4ac65   7/6/2015 22:13              No                  Parent
# 0b2392583c236653  2/10/2015 18:14              No                  Parent
#
#                  age_diagnosed   unit  \
# survey_id
# 0100b469f4db4242           2.5  years
# 01d86333e4604f40             4  years
# 024d1aaabac2af2b             4  years
# 050a74c5d1e4ac65             3  years
# 0b2392583c236653          1.66  years
#
#                                              initial_identification  \
# survey_id
# 0100b469f4db4242                                       Psychologist
# 01d86333e4604f40                                  neuropsychiatrist
# 024d1aaabac2af2b  Psychologist, Developmental Pediatrician, OT a...
# 050a74c5d1e4ac65                         Developmental Pediatrician
# 0b2392583c236653                                       Psychiatrist
#
#                                                  testings_performed  \
# survey_id
# 0100b469f4db4242  ADOS (Autism Diagnostic Observation Scale), GA...
# 01d86333e4604f40  ADOS (Autism Diagnostic Observation Scale), AD...
# 024d1aaabac2af2b  ADOS (Autism Diagnostic Observation Scale), AD...
# 050a74c5d1e4ac65  ADOS (Autism Diagnostic Observation Scale), Di...
# 0b2392583c236653         ADOS (Autism Diagnostic Observation Scale)
#
#                                                       symptom_onset  \
# survey_id
# 0100b469f4db4242  non-regressive (not accompanied by a loss of p...
# 01d86333e4604f40                                         regressive
# 024d1aaabac2af2b                                    non-regressive
# 050a74c5d1e4ac65                                    non-regressive
# 0b2392583c236653                                        regressive
#
#                  social_communication_deficit_intensity  \
# survey_id
# 0100b469f4db4242                      Moderate deficits
# 01d86333e4604f40                          Mild deficits
# 024d1aaabac2af2b                      Moderate deficits
# 050a74c5d1e4ac65                        Severe deficits
# 0b2392583c236653                        Severe deficits
#
#                                             spoken_language     ...       \
# survey_id                                                       ...
# 0100b469f4db4242                                        Yes     ...
# 01d86333e4604f40                                        Yes     ...
# 024d1aaabac2af2b                                        Yes     ...
# 050a74c5d1e4ac65  Speaks but cannot speak in full sentences     ...
# 0b2392583c236653                      No – unable to speak.     ...
#
#                     shannon_1k Unnamed: 444 Unnamed: 445 Unnamed: 446  \
# survey_id
# 0100b469f4db4242           NaN          NaN          NaN          NaN
# 01d86333e4604f40  5.9494511366          NaN          NaN          NaN
# 024d1aaabac2af2b           NaN          NaN          NaN          NaN
# 050a74c5d1e4ac65           NaN          NaN          NaN          NaN
# 0b2392583c236653           NaN          NaN          NaN          NaN
#
#                  Unnamed: 447 Unnamed: 448 Unnamed: 449 Unnamed: 450  \
# survey_id
# 0100b469f4db4242          NaN          NaN          NaN          NaN
# 01d86333e4604f40          NaN          NaN          NaN          NaN
# 024d1aaabac2af2b          NaN          NaN          NaN          NaN
# 050a74c5d1e4ac65          NaN          NaN          NaN          NaN
# 0b2392583c236653          NaN          NaN          NaN          NaN
#
#                  Unnamed: 451 Unnamed: 452
# survey_id
# 0100b469f4db4242          NaN          NaN
# 01d86333e4604f40          NaN          NaN
# 024d1aaabac2af2b          NaN          NaN
# 050a74c5d1e4ac65          NaN          NaN
# 0b2392583c236653          NaN          NaN
#
# [5 rows x 544 columns]

# %%
ag_asd_metadata=ag_asd_metadata.set_index("#SampleID")

# %%
ag_asd_metadata.to_csv("ag_asd_metadata")

# %%
ag_asd_metadata.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b03ecb7a0318> in <module>()
# ----> 1 ag_asd_metadata.shape
#
# NameError: name 'ag_asd_metadata' is not defined
